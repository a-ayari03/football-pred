# %%
import pandas as pd
import numpy as np
import json
import os
from tqdm import tqdm
import time
import re
from IPython.display import display
from pathlib import Path 
DATAPATH = Path(r'Data')

# %%
def remove_tags(string):
    """
    Clean text from html tag using regex
    """
    result = re.sub('<.*?>','',string)
    return result

# %%
def new_date_features(df) :
    
    df['date'] = pd.to_datetime(df['date'])
    df['year'] = df.date.dt.year 
    df['quarter'] = df.date.dt.quarter
    df['month'] = df.date.dt.month  
    df['week'] = df.date.dt.week 
    df['day'] = df.date.dt.day  
    df['weekday'] = df.date.dt.weekday
    
    df['is_monday'] = np.where((df['weekday'] == 0), 1, 0)
    df['is_tuesday'] = np.where((df['weekday'] == 1), 1, 0)
    df['is_wednesday'] = np.where((df['weekday'] == 2), 1, 0)
    df['is_thursday'] = np.where((df['weekday'] == 3), 1, 0)
    df['is_friday'] = np.where((df['weekday'] == 4), 1, 0)
    df['is_saturday'] = np.where((df['weekday'] == 5), 1, 0)
    df['is_sunday'] = np.where((df['weekday'] == 6), 1, 0)
    
    return df

# %%
def new_features(df) :
    
    # remove html tags > normalize between 0-1
    df["possession_home"] = df["possession_home"].apply(lambda x : int(remove_tags(str(x)).strip("%"))/100 ) 
    df["possession_away"] = df["possession_away"].apply(lambda x : int(remove_tags(str(x)).strip("%"))/100 )
    # --
    df["shot_on_target_home_raw"] = df["shot_on_target_home"].apply(lambda x : remove_tags(str(x))) 
    df["shot_on_target_away_raw"] = df["shot_on_target_away"].apply(lambda x : remove_tags(str(x)))
    
    # regex values : [shot on target, total shot, prc of shot on target] or [prc of shot on target, total shot, shot on target]
    
    df["shot_on_target_home"] = df["shot_on_target_home_raw"].apply(lambda x : int(re.findall(r"\d+",
                                                                                          re.sub('\d+%',' ',x))[0]))
    df["shot_total_home"] = df["shot_on_target_home_raw"].apply(lambda x : int(re.findall(r"\d+",
                                                                                      re.sub('\d+%',' ',x))[1]))
    df["shot_on_target_away"] = df["shot_on_target_away_raw"].apply(lambda x : int(re.findall(r"\d+",
                                                                                          re.sub('\d+%',' ',x))[0]))
    df["shot_total_away"] = df["shot_on_target_away_raw"].apply(lambda x : int(re.findall(r"\d+",
                                                                                      re.sub('\d+%',' ',x))[1]))
    # --
    df["saves_home_raw"] = df["saves_home"].apply(lambda x : remove_tags(str(x))) 
    df["saves_away_raw"] = df["saves_away"].apply(lambda x : remove_tags(str(x)))
    
    df["saves_home"] = df["saves_home_raw"].apply(lambda x : int(re.findall(r"\d+",
                                                                                          re.sub('\d+%',' ',x))[0]))
    df["saves_total_home"] = df["saves_home_raw"].apply(lambda x : int(re.findall(r"\d+",
                                                                                      re.sub('\d+%',' ',x))[1]))
    df["saves_away"] = df["saves_away_raw"].apply(lambda x : int(re.findall(r"\d+",
                                                                                          re.sub('\d+%',' ',x))[0]))
    df["saves_total_away"] = df["saves_away_raw"].apply(lambda x : int(re.findall(r"\d+",
                                                                                      re.sub('\d+%',' ',x))[1]))
    df["goal_home"] = df["score"].apply(lambda x : int(re.split(r"–|-",x)[0]))
    df["goal_away"] = df["score"].apply(lambda x : int(re.split(r"–|-",x)[1]))
    
    # Victory : 3 pts, Draw : 1 pts and Loose : 0 pts
    df["points_result_home"] = np.where(eda_df['goal_home'] > eda_df['goal_away'] , 3,
                                        np.where(eda_df['goal_home'] == eda_df['goal_away'], 1, 0))
    
    df["points_result_away"] = np.where(eda_df['goal_away'] > eda_df['goal_home'] , 3,
                                        np.where(eda_df['goal_away'] == eda_df['goal_home'], 1, 0))
    
    df = df.drop(df.filter(regex='_raw').columns, axis=1)
    return df

# %%
def new_cumul_sum_features(df) :
    """
    This are only cumsum features to keep track of features week by week
    TODO : We need to supress thoses column because of data leakage. 
    Solution : remove last row to only keep the cumulative sum before the last row. but if no value (first row) replace by np.NaN
    """
    
    features = ['points_result', 'shot_on_target', 'saves', 'shot_total',
       'saves_total', 'goal', 'points_result_against',
       'shot_on_target_against', 'saves_against', 'shot_total_against',
       'saves_total_against', 'goal_against',]
    
    for feature in features :
        col = {f"cumul_{feature}" :
                           df.groupby(
                            ["season", "team"], sort = False)[f'{feature}'].agg('cumsum')}
        df = df.assign(**col)
        
    df["goal_difference"] = df["cumul_goal"] - df["cumul_goal_against"]
                               
    return df

# %%
def new_cumul_average_features(df) :
    
    # Average cumul of point
    features = ['points_result', 'shot_on_target', 'saves', 'shot_total',
       'saves_total', 'goal', 'points_result_against',
       'shot_on_target_against', 'saves_against', 'shot_total_against',
       'saves_total_against', 'goal_against',]
    for feature in features :
    
        col = {f"cumul_average_{feature}" :
                       df.groupby(
                        ["season", "team"], sort = False)[f'{feature}'].transform(
                        lambda x: x.expanding().mean())}

        df = df.assign(**col)
    
    
    
    return df

# %% [markdown]
# ### Moving average features

# %% [markdown]
# points_result, goal, goal_against, goal-goal_against

# %%
def new_moving_average_features(df) :
    
    # moving average for
    features = ['points_result', 'shot_on_target', 'saves', 'shot_total',
       'saves_total', 'goal', 'points_result_against',
       'shot_on_target_against', 'saves_against', 'shot_total_against',
       'saves_total_against', 'goal_against',]
    
    for feature in features :
        for i in [1,2,3,4,5,6] :
            # create a column moving_average_1_point_result
            #  closed = "right" mean that we 
            col = {f"moving_average_{i}_{feature}" :
                   df.groupby(
                    ["season", "team"], sort = False)[f'{feature}'].transform(
                    lambda x: x.rolling(i, closed = 'left').mean())}
            df = df.assign(**col)
    
    return df

# %% [markdown]
# ### Fatigue features

# %%
def new_fatigues_features(df) :
    
    # moving average for
    for i in [2,3,4,5,6] :
        df["date_timestamp"] = df.groupby(["season", "team"], sort = False)['date'].transform(
            lambda y: y.rolling(i))
        
        col = {f"date_timestamp" :
               df.groupby(["season", "team"], sort = False)['date'].transform(
                   lambda y: y.rolling(i))}
        
        df = df.assign(**col)
        
        df[f"fatigue_{i-1}_match"] = df[f"date_timestamp"].apply(lambda x : (x.iloc[-1] - x.iloc[0]) if len(x)>=i else np.nan)
        df[f"fatigue_{i-1}_match"] = df[f"fatigue_{i-1}_match"].apply(lambda x : abs(x.days) if x != np.nan else np.nan)
        
    df = df.drop("date_timestamp", axis = 1)
        
    return df

# %% [markdown]
# # Production

# %%
filepath = 'Ligue-1-2015-2022.csv'

# %%
df_raw = pd.read_csv(DATAPATH /filepath)

# %%
features = ['gameweek', 'dayofweek', 'date', 'start_time', 'home_team',
 'score', 'away_team',
 'season', 'possession_home', 'possession_away',
 'shot_on_target_home', 'shot_on_target_away', 'saves_home',
 'saves_away'
           ]

# %%
eda_df = df_raw
eda_df = eda_df[features].dropna(axis = 0)
eda_df["SEASON_ID"] = eda_df['season'].astype('category').cat.codes
eda_df = new_date_features(eda_df)
eda_df = new_features(eda_df)
# Out:
# C:\Users\alexa\AppData\Local\Temp/ipykernel_16860/964728274.py:7: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   df['week'] = df.date.dt.week

# %%
#SEASON = "2015-2016"
#df_unique = eda_df.query(f"(season == '{SEASON}')").drop_duplicates()
df_unique = eda_df.drop_duplicates()

# %%
features_home = ["gameweek", "season",
                 "date", "start_time", "home_team",
                 "points_result_home", "shot_on_target_home",
                "saves_home", "shot_total_home", "saves_total_home",
                "goal_home",
                "points_result_away", "shot_on_target_away", 
                "saves_away", "shot_total_away", "saves_total_away",
                "goal_away"]

features_away = ["gameweek", "season", 
                 "date", "start_time","away_team",
                 "points_result_away", "shot_on_target_away", 
                "saves_away", "shot_total_away", "saves_total_away",
                "goal_away",
                "points_result_home", "shot_on_target_home",
                "saves_home", "shot_total_home", "saves_total_home",
                "goal_home",]

# %%
# We split home and away match for each team and concatenate after
home_df = df_unique[features_home].groupby(features_home).first().reset_index()
home_df.rename(columns=lambda x: x.replace("_home",'') if "_home" in x else(x.replace("home_",'') if "home_" in x else x), inplace = True)
home_df.rename(columns=lambda x: x.replace("_away",'_against') if "_away" in x else(x.replace("away_",'against_') if "away_" in x else x), inplace = True)

away_df = df_unique[features_away].groupby(features_away).first().reset_index()
away_df.rename(columns=lambda x: x.replace("_away",'') if "_away" in x else(x.replace("away_",'') if "away_" in x else x), inplace = True)
away_df.rename(columns=lambda x: x.replace("_home",'_against') if "_home" in x else(x.replace("home_",'against_') if "home_" in x else x), inplace = True)

concat_team = pd.concat([home_df, away_df])
concat_team = concat_team.sort_values(by = ['season', "gameweek"])

# %%
league_table = new_cumul_sum_features(concat_team)
league_table = new_cumul_average_features(league_table)
league_table = new_moving_average_features(league_table)
league_table = new_fatigues_features(league_table)
league_table_test = league_table.copy()

# %%
league_table[league_table["team"] == "Paris S-G"].head()
# Out:
#      gameweek     season       date start_time       team  points_result  \
# 0         1.0  2015-2016 2015-08-07      20:30  Paris S-G              3
# 79        2.0  2015-2016 2015-08-16      21:00  Paris S-G              3
# 140       3.0  2015-2016 2015-08-21      20:30  Paris S-G              3
# 219       4.0  2015-2016 2015-08-30      21:00  Paris S-G              3
# 280       5.0  2015-2016 2015-09-11      20:30  Paris S-G              1
#
#      shot_on_target  saves  shot_total  saves_total  ...  \
# 0                 3      2           7            2  ...
# 79                6      2          18            2  ...
# 140               5      3           9            3  ...
# 219               8      2          19            2  ...
# 280               5      1          19            3  ...
#
#      moving_average_2_goal_against  moving_average_3_goal_against  \
# 0                              NaN                            NaN
# 79                             NaN                            NaN
# 140                            0.0                            NaN
# 219                            0.0                            0.0
# 280                            0.0                            0.0
#
#      moving_average_4_goal_against  moving_average_5_goal_against  \
# 0                              NaN                            NaN
# 79                             NaN                            NaN
# 140                            NaN                            NaN
# 219                            NaN                            NaN
# 280                            0.0                            NaN
#
#      moving_average_6_goal_against  fatigue_1_match  fatigue_2_match  \
# 0                              NaN              NaN              NaN
# 79                             NaN              9.0              NaN
# 140                            NaN              5.0             14.0
# 219                            NaN              9.0             14.0
# 280                            NaN             12.0             21.0
#
#      fatigue_3_match  fatigue_4_match  fatigue_5_match
# 0                NaN              NaN              NaN
# 79               NaN              NaN              NaN
# 140              NaN              NaN              NaN
# 219             23.0              NaN              NaN
# 280             26.0             35.0              NaN
#
# [5 rows x 119 columns]

# %%
league_table.to_csv(DATAPATH / f"league_table_{filepath}",index=False)

# %% [markdown]
# ## Update original CSV with transformed data

# %%
def new_unique_id(df) :
    
    # GAME_ID : YEAR_id, ex : 2022380 : last game of 2022
    df["dummy_id"] = 1
    df["id"] = df.groupby('season')["dummy_id"].agg('cumsum')
    df["GAME_ID"] = df.apply(lambda x : int(f"{x['year']}{x['id']:03d}"), axis = 1)
    
    df = df.drop(["dummy_id", "id"], axis = 1)
    
    return df

# %%
eda_df = new_unique_id(eda_df)
league_table["TEAM_ID"] = league_table['team'].astype('category').cat.codes

# %%
with pd.option_context('display.max_columns', None) :
    display(league_table[league_table['team']== 'Paris S-G'].head())
# Out:
#      gameweek     season       date start_time       team  points_result  \
# 0         1.0  2015-2016 2015-08-07      20:30  Paris S-G              3
# 79        2.0  2015-2016 2015-08-16      21:00  Paris S-G              3
# 140       3.0  2015-2016 2015-08-21      20:30  Paris S-G              3
# 219       4.0  2015-2016 2015-08-30      21:00  Paris S-G              3
# 280       5.0  2015-2016 2015-09-11      20:30  Paris S-G              1
#
#      shot_on_target  saves  shot_total  saves_total  goal  \
# 0                 3      2           7            2     1
# 79                6      2          18            2     2
# 140               5      3           9            3     1
# 219               8      2          19            2     3
# 280               5      1          19            3     2
#
#      points_result_against  shot_on_target_against  saves_against  \
# 0                        0                       2              1
# 79                       0                       2              4
# 140                      0                       3              4
# 219                      0                       2              5
# 280                      1                       3              3
#
#      shot_total_against  saves_total_against  goal_against  \
# 0                    12                    3             0
# 79                    8                    6             0
# 140                  10                    5             0
# 219                   3                    8             0
# 280                  10                    5             2
#
#      cumul_points_result  cumul_shot_on_target  cumul_saves  cumul_shot_total  \
# 0                      3                     3            2                 7
# 79                     6                     9            4                25
# 140                    9                    14            7                34
# 219                   12                    22            9                53
# 280                   13                    27           10                72
#
#      cumul_saves_total  cumul_goal  cumul_points_result_against  \
# 0                    2           1                            0
# 79                   4           3                            0
# 140                  7           4                            0
# 219                  9           7                            0
# 280                 12           9                            1
#
#      cumul_shot_on_target_against  cumul_saves_against  \
# 0                               2                    1
# 79                              4                    5
# 140                             7                    9
# 219                             9                   14
# 280                            12                   17
#
#      cumul_shot_total_against  cumul_saves_total_against  cumul_goal_against  \
# 0                          12                          3                   0
# 79                         20                          9                   0
# 140                        30                         14                   0
# 219                        33                         22                   0
# 280                        43                         27                   2
#
#      goal_difference  cumul_average_points_result  \
# 0                  1                          3.0
# 79                 3                          3.0
# 140                4                          3.0
# 219                7                          3.0
# 280                7                          2.6
#
#      cumul_average_shot_on_target  cumul_average_saves  \
# 0                        3.000000             2.000000
# 79                       4.500000             2.000000
# 140                      4.666667             2.333333
# 219                      5.500000             2.250000
# 280                      5.400000             2.000000
#
#      cumul_average_shot_total  cumul_average_saves_total  cumul_average_goal  \
# 0                    7.000000                   2.000000            1.000000
# 79                  12.500000                   2.000000            1.500000
# 140                 11.333333                   2.333333            1.333333
# 219                 13.250000                   2.250000            1.750000
# 280                 14.400000                   2.400000            1.800000
#
#      cumul_average_points_result_against  \
# 0                                    0.0
# 79                                   0.0
# 140                                  0.0
# 219                                  0.0
# 280                                  0.2
#
#      cumul_average_shot_on_target_against  cumul_average_saves_against  \
# 0                                2.000000                          1.0
# 79                               2.000000                          2.5
# 140                              2.333333                          3.0
# 219                              2.250000                          3.5
# 280                              2.400000                          3.4
#
#      cumul_average_shot_total_against  cumul_average_saves_total_against  \
# 0                               12.00                           3.000000
# 79                              10.00                           4.500000
# 140                             10.00                           4.666667
# 219                              8.25                           5.500000
# 280                              8.60                           5.400000
#
#      cumul_average_goal_against  moving_average_1_points_result  \
# 0                           0.0                             NaN
# 79                          0.0                             3.0
# 140                         0.0                             3.0
# 219                         0.0                             3.0
# 280                         0.4                             3.0
#
#      moving_average_2_points_result  moving_average_3_points_result  \
# 0                               NaN                             NaN
# 79                              NaN                             NaN
# 140                             3.0                             NaN
# 219                             3.0                             3.0
# 280                             3.0                             3.0
#
#      moving_average_4_points_result  moving_average_5_points_result  \
# 0                               NaN                             NaN
# 79                              NaN                             NaN
# 140                             NaN                             NaN
# 219                             NaN                             NaN
# 280                             3.0                             NaN
#
#      moving_average_6_points_result  moving_average_1_shot_on_target  \
# 0                               NaN                              NaN
# 79                              NaN                              3.0
# 140                             NaN                              6.0
# 219                             NaN                              5.0
# 280                             NaN                              8.0
#
#      moving_average_2_shot_on_target  moving_average_3_shot_on_target  \
# 0                                NaN                              NaN
# 79                               NaN                              NaN
# 140                              4.5                              NaN
# 219                              5.5                         4.666667
# 280                              6.5                         6.333333
#
#      moving_average_4_shot_on_target  moving_average_5_shot_on_target  \
# 0                                NaN                              NaN
# 79                               NaN                              NaN
# 140                              NaN                              NaN
# 219                              NaN                              NaN
# 280                              5.5                              NaN
#
#      moving_average_6_shot_on_target  moving_average_1_saves  \
# 0                                NaN                     NaN
# 79                               NaN                     2.0
# 140                              NaN                     2.0
# 219                              NaN                     3.0
# 280                              NaN                     2.0
#
#      moving_average_2_saves  moving_average_3_saves  moving_average_4_saves  \
# 0                       NaN                     NaN                     NaN
# 79                      NaN                     NaN                     NaN
# 140                     2.0                     NaN                     NaN
# 219                     2.5                2.333333                     NaN
# 280                     2.5                2.333333                    2.25
#
#      moving_average_5_saves  moving_average_6_saves  \
# 0                       NaN                     NaN
# 79                      NaN                     NaN
# 140                     NaN                     NaN
# 219                     NaN                     NaN
# 280                     NaN                     NaN
#
#      moving_average_1_shot_total  moving_average_2_shot_total  \
# 0                            NaN                          NaN
# 79                           7.0                          NaN
# 140                         18.0                         12.5
# 219                          9.0                         13.5
# 280                         19.0                         14.0
#
#      moving_average_3_shot_total  moving_average_4_shot_total  \
# 0                            NaN                          NaN
# 79                           NaN                          NaN
# 140                          NaN                          NaN
# 219                    11.333333                          NaN
# 280                    15.333333                        13.25
#
#      moving_average_5_shot_total  moving_average_6_shot_total  \
# 0                            NaN                          NaN
# 79                           NaN                          NaN
# 140                          NaN                          NaN
# 219                          NaN                          NaN
# 280                          NaN                          NaN
#
#      moving_average_1_saves_total  moving_average_2_saves_total  \
# 0                             NaN                           NaN
# 79                            2.0                           NaN
# 140                           2.0                           2.0
# 219                           3.0                           2.5
# 280                           2.0                           2.5
#
#      moving_average_3_saves_total  moving_average_4_saves_total  \
# 0                             NaN                           NaN
# 79                            NaN                           NaN
# 140                           NaN                           NaN
# 219                      2.333333                           NaN
# 280                      2.333333                          2.25
#
#      moving_average_5_saves_total  moving_average_6_saves_total  \
# 0                             NaN                           NaN
# 79                            NaN                           NaN
# 140                           NaN                           NaN
# 219                           NaN                           NaN
# 280                           NaN                           NaN
#
#      moving_average_1_goal  moving_average_2_goal  moving_average_3_goal  \
# 0                      NaN                    NaN                    NaN
# 79                     1.0                    NaN                    NaN
# 140                    2.0                    1.5                    NaN
# 219                    1.0                    1.5               1.333333
# 280                    3.0                    2.0               2.000000
#
#      moving_average_4_goal  moving_average_5_goal  moving_average_6_goal  \
# 0                      NaN                    NaN                    NaN
# 79                     NaN                    NaN                    NaN
# 140                    NaN                    NaN                    NaN
# 219                    NaN                    NaN                    NaN
# 280                   1.75                    NaN                    NaN
#
#      moving_average_1_points_result_against  \
# 0                                       NaN
# 79                                      0.0
# 140                                     0.0
# 219                                     0.0
# 280                                     0.0
#
#      moving_average_2_points_result_against  \
# 0                                       NaN
# 79                                      NaN
# 140                                     0.0
# 219                                     0.0
# 280                                     0.0
#
#      moving_average_3_points_result_against  \
# 0                                       NaN
# 79                                      NaN
# 140                                     NaN
# 219                                     0.0
# 280                                     0.0
#
#      moving_average_4_points_result_against  \
# 0                                       NaN
# 79                                      NaN
# 140                                     NaN
# 219                                     NaN
# 280                                     0.0
#
#      moving_average_5_points_result_against  \
# 0                                       NaN
# 79                                      NaN
# 140                                     NaN
# 219                                     NaN
# 280                                     NaN
#
#      moving_average_6_points_result_against  \
# 0                                       NaN
# 79                                      NaN
# 140                                     NaN
# 219                                     NaN
# 280                                     NaN
#
#      moving_average_1_shot_on_target_against  \
# 0                                        NaN
# 79                                       2.0
# 140                                      2.0
# 219                                      3.0
# 280                                      2.0
#
#      moving_average_2_shot_on_target_against  \
# 0                                        NaN
# 79                                       NaN
# 140                                      2.0
# 219                                      2.5
# 280                                      2.5
#
#      moving_average_3_shot_on_target_against  \
# 0                                        NaN
# 79                                       NaN
# 140                                      NaN
# 219                                 2.333333
# 280                                 2.333333
#
#      moving_average_4_shot_on_target_against  \
# 0                                        NaN
# 79                                       NaN
# 140                                      NaN
# 219                                      NaN
# 280                                     2.25
#
#      moving_average_5_shot_on_target_against  \
# 0                                        NaN
# 79                                       NaN
# 140                                      NaN
# 219                                      NaN
# 280                                      NaN
#
#      moving_average_6_shot_on_target_against  moving_average_1_saves_against  \
# 0                                        NaN                             NaN
# 79                                       NaN                             1.0
# 140                                      NaN                             4.0
# 219                                      NaN                             4.0
# 280                                      NaN                             5.0
#
#      moving_average_2_saves_against  moving_average_3_saves_against  \
# 0                               NaN                             NaN
# 79                              NaN                             NaN
# 140                             2.5                             NaN
# 219                             4.0                        3.000000
# 280                             4.5                        4.333333
#
#      moving_average_4_saves_against  moving_average_5_saves_against  \
# 0                               NaN                             NaN
# 79                              NaN                             NaN
# 140                             NaN                             NaN
# 219                             NaN                             NaN
# 280                             3.5                             NaN
#
#      moving_average_6_saves_against  moving_average_1_shot_total_against  \
# 0                               NaN                                  NaN
# 79                              NaN                                 12.0
# 140                             NaN                                  8.0
# 219                             NaN                                 10.0
# 280                             NaN                                  3.0
#
#      moving_average_2_shot_total_against  moving_average_3_shot_total_against  \
# 0                                    NaN                                  NaN
# 79                                   NaN                                  NaN
# 140                                 10.0                                  NaN
# 219                                  9.0                                 10.0
# 280                                  6.5                                  7.0
#
#      moving_average_4_shot_total_against  moving_average_5_shot_total_against  \
# 0                                    NaN                                  NaN
# 79                                   NaN                                  NaN
# 140                                  NaN                                  NaN
# 219                                  NaN                                  NaN
# 280                                 8.25                                  NaN
#
#      moving_average_6_shot_total_against  \
# 0                                    NaN
# 79                                   NaN
# 140                                  NaN
# 219                                  NaN
# 280                                  NaN
#
#      moving_average_1_saves_total_against  \
# 0                                     NaN
# 79                                    3.0
# 140                                   6.0
# 219                                   5.0
# 280                                   8.0
#
#      moving_average_2_saves_total_against  \
# 0                                     NaN
# 79                                    NaN
# 140                                   4.5
# 219                                   5.5
# 280                                   6.5
#
#      moving_average_3_saves_total_against  \
# 0                                     NaN
# 79                                    NaN
# 140                                   NaN
# 219                              4.666667
# 280                              6.333333
#
#      moving_average_4_saves_total_against  \
# 0                                     NaN
# 79                                    NaN
# 140                                   NaN
# 219                                   NaN
# 280                                   5.5
#
#      moving_average_5_saves_total_against  \
# 0                                     NaN
# 79                                    NaN
# 140                                   NaN
# 219                                   NaN
# 280                                   NaN
#
#      moving_average_6_saves_total_against  moving_average_1_goal_against  \
# 0                                     NaN                            NaN
# 79                                    NaN                            0.0
# 140                                   NaN                            0.0
# 219                                   NaN                            0.0
# 280                                   NaN                            0.0
#
#      moving_average_2_goal_against  moving_average_3_goal_against  \
# 0                              NaN                            NaN
# 79                             NaN                            NaN
# 140                            0.0                            NaN
# 219                            0.0                            0.0
# 280                            0.0                            0.0
#
#      moving_average_4_goal_against  moving_average_5_goal_against  \
# 0                              NaN                            NaN
# 79                             NaN                            NaN
# 140                            NaN                            NaN
# 219                            NaN                            NaN
# 280                            0.0                            NaN
#
#      moving_average_6_goal_against  fatigue_1_match  fatigue_2_match  \
# 0                              NaN              NaN              NaN
# 79                             NaN              9.0              NaN
# 140                            NaN              5.0             14.0
# 219                            NaN              9.0             14.0
# 280                            NaN             12.0             21.0
#
#      fatigue_3_match  fatigue_4_match  fatigue_5_match  TEAM_ID
# 0                NaN              NaN              NaN       22
# 79               NaN              NaN              NaN       22
# 140              NaN              NaN              NaN       22
# 219             23.0              NaN              NaN       22
# 280             26.0             35.0              NaN       22

# %%
# We merge at first the features of the HOME teams with the suffix HOME
games = eda_df.merge(
    league_table.add_suffix('_HOME'), how = 'left', 
    left_on = ['gameweek', 'home_team', 'season'],
    right_on = ['gameweek_HOME', 'team_HOME', 'season_HOME'])

# Then we add the AWAY team features
games = games.merge(
    league_table.add_suffix('_AWAY'), how = 'left', 
    left_on = ['gameweek', 'away_team', 'season'],
    right_on = ['gameweek_AWAY', 'team_AWAY', 'season_AWAY'])

# %%
features_to_supress = ["season_HOME", "date_HOME", "start_time_HOME", "team_HOME",
                       "gameweek_AWAY", "season_AWAY", "date_AWAY", "start_time_AWAY", "team_AWAY"]
for f in features_to_supress :
    games = games.drop(f, axis = 1)

# %%
with pd.option_context('display.max_columns', None) :
    display(games[games["TEAM_ID_AWAY"] == 22].head(3))
# Out:
#     GAME_ID  TEAM_ID_HOME  TEAM_ID_AWAY  gameweek     season  possession_home  \
# 0   2015001            11            22       1.0  2015-2016             0.52
# 20  2015021            17            22       3.0  2015-2016             0.36
# 39  2015040            16            22       4.0  2015-2016             0.29
#
#     possession_away  shot_on_target_home  shot_on_target_away  saves_home  \
# 0              0.48                    2                    3           1
# 20             0.64                    3                    5           4
# 39             0.71                    2                    8           5
#
#     saves_away  year  quarter  month  week  day  weekday  is_monday  \
# 0            2  2015        3      8    32    7        4          0
# 20           3  2015        3      8    34   21        4          0
# 39           2  2015        3      8    35   30        6          0
#
#     is_tuesday  is_wednesday  is_thursday  is_friday  is_saturday  is_sunday  \
# 0            0             0            0          1            0          0
# 20           0             0            0          1            0          0
# 39           0             0            0          0            0          1
#
#     shot_total_home  shot_total_away  saves_total_home  saves_total_away  \
# 0                12                7                 3                 2
# 20               10                9                 5                 3
# 39                3               19                 8                 2
#
#     goal_home  goal_away  points_result_home  points_result_away dayofweek  \
# 0           0          1                   0                   3       Fri
# 20          0          1                   0                   3       Fri
# 39          0          3                   0                   3       Sun
#
#          date start_time    home_team score  away_team  SEASON_ID  \
# 0  2015-08-07      20:30        Lille   0–1  Paris S-G          0
# 20 2015-08-21      20:30  Montpellier   0–1  Paris S-G          0
# 39 2015-08-30      21:00       Monaco   0–3  Paris S-G          0
#
#     gameweek_HOME  points_result_HOME  shot_on_target_HOME  saves_HOME  \
# 0             1.0                   0                    2           1
# 20            3.0                   0                    3           4
# 39            4.0                   0                    2           5
#
#     shot_total_HOME  saves_total_HOME  goal_HOME  points_result_against_HOME  \
# 0                12                 3          0                           3
# 20               10                 5          0                           3
# 39                3                 8          0                           3
#
#     shot_on_target_against_HOME  saves_against_HOME  shot_total_against_HOME  \
# 0                             3                   2                        7
# 20                            5                   3                        9
# 39                            8                   2                       19
#
#     saves_total_against_HOME  goal_against_HOME  cumul_points_result_HOME  \
# 0                          2                  1                         0
# 20                         3                  1                         0
# 39                         2                  3                         5
#
#     cumul_shot_on_target_HOME  cumul_saves_HOME  cumul_shot_total_HOME  \
# 0                           2                 1                     12
# 20                          7                10                     25
# 39                         14                11                     44
#
#     cumul_saves_total_HOME  cumul_goal_HOME  cumul_points_result_against_HOME  \
# 0                        3                0                                 3
# 20                      13                0                                 9
# 39                      16                3                                 5
#
#     cumul_shot_on_target_against_HOME  cumul_saves_against_HOME  \
# 0                                   3                         2
# 20                                 13                         7
# 39                                 16                        11
#
#     cumul_shot_total_against_HOME  cumul_saves_total_against_HOME  \
# 0                               7                               2
# 20                             35                               7
# 39                             46                              14
#
#     cumul_goal_against_HOME  goal_difference_HOME  \
# 0                         1                    -1
# 20                        4                    -4
# 39                        5                    -2
#
#     cumul_average_points_result_HOME  cumul_average_shot_on_target_HOME  \
# 0                               0.00                           2.000000
# 20                              0.00                           2.333333
# 39                              1.25                           3.500000
#
#     cumul_average_saves_HOME  cumul_average_shot_total_HOME  \
# 0                   1.000000                      12.000000
# 20                  3.333333                       8.333333
# 39                  2.750000                      11.000000
#
#     cumul_average_saves_total_HOME  cumul_average_goal_HOME  \
# 0                         3.000000                     0.00
# 20                        4.333333                     0.00
# 39                        4.000000                     0.75
#
#     cumul_average_points_result_against_HOME  \
# 0                                       3.00
# 20                                      3.00
# 39                                      1.25
#
#     cumul_average_shot_on_target_against_HOME  \
# 0                                    3.000000
# 20                                   4.333333
# 39                                   4.000000
#
#     cumul_average_saves_against_HOME  cumul_average_shot_total_against_HOME  \
# 0                           2.000000                               7.000000
# 20                          2.333333                              11.666667
# 39                          2.750000                              11.500000
#
#     cumul_average_saves_total_against_HOME  cumul_average_goal_against_HOME  \
# 0                                 2.000000                         1.000000
# 20                                2.333333                         1.333333
# 39                                3.500000                         1.250000
#
#     moving_average_1_points_result_HOME  moving_average_2_points_result_HOME  \
# 0                                   NaN                                  NaN
# 20                                  0.0                                  0.0
# 39                                  1.0                                  1.0
#
#     moving_average_3_points_result_HOME  moving_average_4_points_result_HOME  \
# 0                                   NaN                                  NaN
# 20                                  NaN                                  NaN
# 39                             1.666667                                  NaN
#
#     moving_average_5_points_result_HOME  moving_average_6_points_result_HOME  \
# 0                                   NaN                                  NaN
# 20                                  NaN                                  NaN
# 39                                  NaN                                  NaN
#
#     moving_average_1_shot_on_target_HOME  \
# 0                                    NaN
# 20                                   0.0
# 39                                   3.0
#
#     moving_average_2_shot_on_target_HOME  \
# 0                                    NaN
# 20                                   2.0
# 39                                   3.0
#
#     moving_average_3_shot_on_target_HOME  \
# 0                                    NaN
# 20                                   NaN
# 39                                   4.0
#
#     moving_average_4_shot_on_target_HOME  \
# 0                                    NaN
# 20                                   NaN
# 39                                   NaN
#
#     moving_average_5_shot_on_target_HOME  \
# 0                                    NaN
# 20                                   NaN
# 39                                   NaN
#
#     moving_average_6_shot_on_target_HOME  moving_average_1_saves_HOME  \
# 0                                    NaN                          NaN
# 20                                   NaN                          2.0
# 39                                   NaN                          3.0
#
#     moving_average_2_saves_HOME  moving_average_3_saves_HOME  \
# 0                           NaN                          NaN
# 20                          3.0                          NaN
# 39                          2.5                          2.0
#
#     moving_average_4_saves_HOME  moving_average_5_saves_HOME  \
# 0                           NaN                          NaN
# 20                          NaN                          NaN
# 39                          NaN                          NaN
#
#     moving_average_6_saves_HOME  moving_average_1_shot_total_HOME  \
# 0                           NaN                               NaN
# 20                          NaN                               4.0
# 39                          NaN                              14.0
#
#     moving_average_2_shot_total_HOME  moving_average_3_shot_total_HOME  \
# 0                                NaN                               NaN
# 20                               7.5                               NaN
# 39                              11.5                         13.666667
#
#     moving_average_4_shot_total_HOME  moving_average_5_shot_total_HOME  \
# 0                                NaN                               NaN
# 20                               NaN                               NaN
# 39                               NaN                               NaN
#
#     moving_average_6_shot_total_HOME  moving_average_1_saves_total_HOME  \
# 0                                NaN                                NaN
# 20                               NaN                                2.0
# 39                               NaN                                4.0
#
#     moving_average_2_saves_total_HOME  moving_average_3_saves_total_HOME  \
# 0                                 NaN                                NaN
# 20                                4.0                                NaN
# 39                                3.0                           2.666667
#
#     moving_average_4_saves_total_HOME  moving_average_5_saves_total_HOME  \
# 0                                 NaN                                NaN
# 20                                NaN                                NaN
# 39                                NaN                                NaN
#
#     moving_average_6_saves_total_HOME  moving_average_1_goal_HOME  \
# 0                                 NaN                         NaN
# 20                                NaN                         0.0
# 39                                NaN                         1.0
#
#     moving_average_2_goal_HOME  moving_average_3_goal_HOME  \
# 0                          NaN                         NaN
# 20                         0.0                         NaN
# 39                         0.5                         1.0
#
#     moving_average_4_goal_HOME  moving_average_5_goal_HOME  \
# 0                          NaN                         NaN
# 20                         NaN                         NaN
# 39                         NaN                         NaN
#
#     moving_average_6_goal_HOME  moving_average_1_points_result_against_HOME  \
# 0                          NaN                                          NaN
# 20                         NaN                                          3.0
# 39                         NaN                                          1.0
#
#     moving_average_2_points_result_against_HOME  \
# 0                                           NaN
# 20                                          3.0
# 39                                          1.0
#
#     moving_average_3_points_result_against_HOME  \
# 0                                           NaN
# 20                                          NaN
# 39                                     0.666667
#
#     moving_average_4_points_result_against_HOME  \
# 0                                           NaN
# 20                                          NaN
# 39                                          NaN
#
#     moving_average_5_points_result_against_HOME  \
# 0                                           NaN
# 20                                          NaN
# 39                                          NaN
#
#     moving_average_6_points_result_against_HOME  \
# 0                                           NaN
# 20                                          NaN
# 39                                          NaN
#
#     moving_average_1_shot_on_target_against_HOME  \
# 0                                            NaN
# 20                                           2.0
# 39                                           4.0
#
#     moving_average_2_shot_on_target_against_HOME  \
# 0                                            NaN
# 20                                           4.0
# 39                                           3.0
#
#     moving_average_3_shot_on_target_against_HOME  \
# 0                                            NaN
# 20                                           NaN
# 39                                      2.666667
#
#     moving_average_4_shot_on_target_against_HOME  \
# 0                                            NaN
# 20                                           NaN
# 39                                           NaN
#
#     moving_average_5_shot_on_target_against_HOME  \
# 0                                            NaN
# 20                                           NaN
# 39                                           NaN
#
#     moving_average_6_shot_on_target_against_HOME  \
# 0                                            NaN
# 20                                           NaN
# 39                                           NaN
#
#     moving_average_1_saves_against_HOME  moving_average_2_saves_against_HOME  \
# 0                                   NaN                                  NaN
# 20                                  0.0                                  2.0
# 39                                  2.0                                  2.5
#
#     moving_average_3_saves_against_HOME  moving_average_4_saves_against_HOME  \
# 0                                   NaN                                  NaN
# 20                                  NaN                                  NaN
# 39                                  3.0                                  NaN
#
#     moving_average_5_saves_against_HOME  moving_average_6_saves_against_HOME  \
# 0                                   NaN                                  NaN
# 20                                  NaN                                  NaN
# 39                                  NaN                                  NaN
#
#     moving_average_1_shot_total_against_HOME  \
# 0                                        NaN
# 20                                      10.0
# 39                                      12.0
#
#     moving_average_2_shot_total_against_HOME  \
# 0                                        NaN
# 20                                      13.0
# 39                                      10.5
#
#     moving_average_3_shot_total_against_HOME  \
# 0                                        NaN
# 20                                       NaN
# 39                                       9.0
#
#     moving_average_4_shot_total_against_HOME  \
# 0                                        NaN
# 20                                       NaN
# 39                                       NaN
#
#     moving_average_5_shot_total_against_HOME  \
# 0                                        NaN
# 20                                       NaN
# 39                                       NaN
#
#     moving_average_6_shot_total_against_HOME  \
# 0                                        NaN
# 20                                       NaN
# 39                                       NaN
#
#     moving_average_1_saves_total_against_HOME  \
# 0                                         NaN
# 20                                        0.0
# 39                                        3.0
#
#     moving_average_2_saves_total_against_HOME  \
# 0                                         NaN
# 20                                        2.0
# 39                                        3.0
#
#     moving_average_3_saves_total_against_HOME  \
# 0                                         NaN
# 20                                        NaN
# 39                                        4.0
#
#     moving_average_4_saves_total_against_HOME  \
# 0                                         NaN
# 20                                        NaN
# 39                                        NaN
#
#     moving_average_5_saves_total_against_HOME  \
# 0                                         NaN
# 20                                        NaN
# 39                                        NaN
#
#     moving_average_6_saves_total_against_HOME  \
# 0                                         NaN
# 20                                        NaN
# 39                                        NaN
#
#     moving_average_1_goal_against_HOME  moving_average_2_goal_against_HOME  \
# 0                                  NaN                                 NaN
# 20                                 1.0                                 1.5
# 39                                 1.0                                 0.5
#
#     moving_average_3_goal_against_HOME  moving_average_4_goal_against_HOME  \
# 0                                  NaN                                 NaN
# 20                                 NaN                                 NaN
# 39                            0.666667                                 NaN
#
#     moving_average_5_goal_against_HOME  moving_average_6_goal_against_HOME  \
# 0                                  NaN                                 NaN
# 20                                 NaN                                 NaN
# 39                                 NaN                                 NaN
#
#     fatigue_1_match_HOME  fatigue_2_match_HOME  fatigue_3_match_HOME  \
# 0                    NaN                   NaN                   NaN
# 20                   6.0                  13.0                   NaN
# 39                   8.0                  16.0                  22.0
#
#     fatigue_4_match_HOME  fatigue_5_match_HOME  points_result_AWAY  \
# 0                    NaN                   NaN                   3
# 20                   NaN                   NaN                   3
# 39                   NaN                   NaN                   3
#
#     shot_on_target_AWAY  saves_AWAY  shot_total_AWAY  saves_total_AWAY  \
# 0                     3           2                7                 2
# 20                    5           3                9                 3
# 39                    8           2               19                 2
#
#     goal_AWAY  points_result_against_AWAY  shot_on_target_against_AWAY  \
# 0           1                           0                            2
# 20          1                           0                            3
# 39          3                           0                            2
#
#     saves_against_AWAY  shot_total_against_AWAY  saves_total_against_AWAY  \
# 0                    1                       12                         3
# 20                   4                       10                         5
# 39                   5                        3                         8
#
#     goal_against_AWAY  cumul_points_result_AWAY  cumul_shot_on_target_AWAY  \
# 0                   0                         3                          3
# 20                  0                         9                         14
# 39                  0                        12                         22
#
#     cumul_saves_AWAY  cumul_shot_total_AWAY  cumul_saves_total_AWAY  \
# 0                  2                      7                       2
# 20                 7                     34                       7
# 39                 9                     53                       9
#
#     cumul_goal_AWAY  cumul_points_result_against_AWAY  \
# 0                 1                                 0
# 20                4                                 0
# 39                7                                 0
#
#     cumul_shot_on_target_against_AWAY  cumul_saves_against_AWAY  \
# 0                                   2                         1
# 20                                  7                         9
# 39                                  9                        14
#
#     cumul_shot_total_against_AWAY  cumul_saves_total_against_AWAY  \
# 0                              12                               3
# 20                             30                              14
# 39                             33                              22
#
#     cumul_goal_against_AWAY  goal_difference_AWAY  \
# 0                         0                     1
# 20                        0                     4
# 39                        0                     7
#
#     cumul_average_points_result_AWAY  cumul_average_shot_on_target_AWAY  \
# 0                                3.0                           3.000000
# 20                               3.0                           4.666667
# 39                               3.0                           5.500000
#
#     cumul_average_saves_AWAY  cumul_average_shot_total_AWAY  \
# 0                   2.000000                       7.000000
# 20                  2.333333                      11.333333
# 39                  2.250000                      13.250000
#
#     cumul_average_saves_total_AWAY  cumul_average_goal_AWAY  \
# 0                         2.000000                 1.000000
# 20                        2.333333                 1.333333
# 39                        2.250000                 1.750000
#
#     cumul_average_points_result_against_AWAY  \
# 0                                        0.0
# 20                                       0.0
# 39                                       0.0
#
#     cumul_average_shot_on_target_against_AWAY  \
# 0                                    2.000000
# 20                                   2.333333
# 39                                   2.250000
#
#     cumul_average_saves_against_AWAY  cumul_average_shot_total_against_AWAY  \
# 0                                1.0                                  12.00
# 20                               3.0                                  10.00
# 39                               3.5                                   8.25
#
#     cumul_average_saves_total_against_AWAY  cumul_average_goal_against_AWAY  \
# 0                                 3.000000                              0.0
# 20                                4.666667                              0.0
# 39                                5.500000                              0.0
#
#     moving_average_1_points_result_AWAY  moving_average_2_points_result_AWAY  \
# 0                                   NaN                                  NaN
# 20                                  3.0                                  3.0
# 39                                  3.0                                  3.0
#
#     moving_average_3_points_result_AWAY  moving_average_4_points_result_AWAY  \
# 0                                   NaN                                  NaN
# 20                                  NaN                                  NaN
# 39                                  3.0                                  NaN
#
#     moving_average_5_points_result_AWAY  moving_average_6_points_result_AWAY  \
# 0                                   NaN                                  NaN
# 20                                  NaN                                  NaN
# 39                                  NaN                                  NaN
#
#     moving_average_1_shot_on_target_AWAY  \
# 0                                    NaN
# 20                                   6.0
# 39                                   5.0
#
#     moving_average_2_shot_on_target_AWAY  \
# 0                                    NaN
# 20                                   4.5
# 39                                   5.5
#
#     moving_average_3_shot_on_target_AWAY  \
# 0                                    NaN
# 20                                   NaN
# 39                              4.666667
#
#     moving_average_4_shot_on_target_AWAY  \
# 0                                    NaN
# 20                                   NaN
# 39                                   NaN
#
#     moving_average_5_shot_on_target_AWAY  \
# 0                                    NaN
# 20                                   NaN
# 39                                   NaN
#
#     moving_average_6_shot_on_target_AWAY  moving_average_1_saves_AWAY  \
# 0                                    NaN                          NaN
# 20                                   NaN                          2.0
# 39                                   NaN                          3.0
#
#     moving_average_2_saves_AWAY  moving_average_3_saves_AWAY  \
# 0                           NaN                          NaN
# 20                          2.0                          NaN
# 39                          2.5                     2.333333
#
#     moving_average_4_saves_AWAY  moving_average_5_saves_AWAY  \
# 0                           NaN                          NaN
# 20                          NaN                          NaN
# 39                          NaN                          NaN
#
#     moving_average_6_saves_AWAY  moving_average_1_shot_total_AWAY  \
# 0                           NaN                               NaN
# 20                          NaN                              18.0
# 39                          NaN                               9.0
#
#     moving_average_2_shot_total_AWAY  moving_average_3_shot_total_AWAY  \
# 0                                NaN                               NaN
# 20                              12.5                               NaN
# 39                              13.5                         11.333333
#
#     moving_average_4_shot_total_AWAY  moving_average_5_shot_total_AWAY  \
# 0                                NaN                               NaN
# 20                               NaN                               NaN
# 39                               NaN                               NaN
#
#     moving_average_6_shot_total_AWAY  moving_average_1_saves_total_AWAY  \
# 0                                NaN                                NaN
# 20                               NaN                                2.0
# 39                               NaN                                3.0
#
#     moving_average_2_saves_total_AWAY  moving_average_3_saves_total_AWAY  \
# 0                                 NaN                                NaN
# 20                                2.0                                NaN
# 39                                2.5                           2.333333
#
#     moving_average_4_saves_total_AWAY  moving_average_5_saves_total_AWAY  \
# 0                                 NaN                                NaN
# 20                                NaN                                NaN
# 39                                NaN                                NaN
#
#     moving_average_6_saves_total_AWAY  moving_average_1_goal_AWAY  \
# 0                                 NaN                         NaN
# 20                                NaN                         2.0
# 39                                NaN                         1.0
#
#     moving_average_2_goal_AWAY  moving_average_3_goal_AWAY  \
# 0                          NaN                         NaN
# 20                         1.5                         NaN
# 39                         1.5                    1.333333
#
#     moving_average_4_goal_AWAY  moving_average_5_goal_AWAY  \
# 0                          NaN                         NaN
# 20                         NaN                         NaN
# 39                         NaN                         NaN
#
#     moving_average_6_goal_AWAY  moving_average_1_points_result_against_AWAY  \
# 0                          NaN                                          NaN
# 20                         NaN                                          0.0
# 39                         NaN                                          0.0
#
#     moving_average_2_points_result_against_AWAY  \
# 0                                           NaN
# 20                                          0.0
# 39                                          0.0
#
#     moving_average_3_points_result_against_AWAY  \
# 0                                           NaN
# 20                                          NaN
# 39                                          0.0
#
#     moving_average_4_points_result_against_AWAY  \
# 0                                           NaN
# 20                                          NaN
# 39                                          NaN
#
#     moving_average_5_points_result_against_AWAY  \
# 0                                           NaN
# 20                                          NaN
# 39                                          NaN
#
#     moving_average_6_points_result_against_AWAY  \
# 0                                           NaN
# 20                                          NaN
# 39                                          NaN
#
#     moving_average_1_shot_on_target_against_AWAY  \
# 0                                            NaN
# 20                                           2.0
# 39                                           3.0
#
#     moving_average_2_shot_on_target_against_AWAY  \
# 0                                            NaN
# 20                                           2.0
# 39                                           2.5
#
#     moving_average_3_shot_on_target_against_AWAY  \
# 0                                            NaN
# 20                                           NaN
# 39                                      2.333333
#
#     moving_average_4_shot_on_target_against_AWAY  \
# 0                                            NaN
# 20                                           NaN
# 39                                           NaN
#
#     moving_average_5_shot_on_target_against_AWAY  \
# 0                                            NaN
# 20                                           NaN
# 39                                           NaN
#
#     moving_average_6_shot_on_target_against_AWAY  \
# 0                                            NaN
# 20                                           NaN
# 39                                           NaN
#
#     moving_average_1_saves_against_AWAY  moving_average_2_saves_against_AWAY  \
# 0                                   NaN                                  NaN
# 20                                  4.0                                  2.5
# 39                                  4.0                                  4.0
#
#     moving_average_3_saves_against_AWAY  moving_average_4_saves_against_AWAY  \
# 0                                   NaN                                  NaN
# 20                                  NaN                                  NaN
# 39                                  3.0                                  NaN
#
#     moving_average_5_saves_against_AWAY  moving_average_6_saves_against_AWAY  \
# 0                                   NaN                                  NaN
# 20                                  NaN                                  NaN
# 39                                  NaN                                  NaN
#
#     moving_average_1_shot_total_against_AWAY  \
# 0                                        NaN
# 20                                       8.0
# 39                                      10.0
#
#     moving_average_2_shot_total_against_AWAY  \
# 0                                        NaN
# 20                                      10.0
# 39                                       9.0
#
#     moving_average_3_shot_total_against_AWAY  \
# 0                                        NaN
# 20                                       NaN
# 39                                      10.0
#
#     moving_average_4_shot_total_against_AWAY  \
# 0                                        NaN
# 20                                       NaN
# 39                                       NaN
#
#     moving_average_5_shot_total_against_AWAY  \
# 0                                        NaN
# 20                                       NaN
# 39                                       NaN
#
#     moving_average_6_shot_total_against_AWAY  \
# 0                                        NaN
# 20                                       NaN
# 39                                       NaN
#
#     moving_average_1_saves_total_against_AWAY  \
# 0                                         NaN
# 20                                        6.0
# 39                                        5.0
#
#     moving_average_2_saves_total_against_AWAY  \
# 0                                         NaN
# 20                                        4.5
# 39                                        5.5
#
#     moving_average_3_saves_total_against_AWAY  \
# 0                                         NaN
# 20                                        NaN
# 39                                   4.666667
#
#     moving_average_4_saves_total_against_AWAY  \
# 0                                         NaN
# 20                                        NaN
# 39                                        NaN
#
#     moving_average_5_saves_total_against_AWAY  \
# 0                                         NaN
# 20                                        NaN
# 39                                        NaN
#
#     moving_average_6_saves_total_against_AWAY  \
# 0                                         NaN
# 20                                        NaN
# 39                                        NaN
#
#     moving_average_1_goal_against_AWAY  moving_average_2_goal_against_AWAY  \
# 0                                  NaN                                 NaN
# 20                                 0.0                                 0.0
# 39                                 0.0                                 0.0
#
#     moving_average_3_goal_against_AWAY  moving_average_4_goal_against_AWAY  \
# 0                                  NaN                                 NaN
# 20                                 NaN                                 NaN
# 39                                 0.0                                 NaN
#
#     moving_average_5_goal_against_AWAY  moving_average_6_goal_against_AWAY  \
# 0                                  NaN                                 NaN
# 20                                 NaN                                 NaN
# 39                                 NaN                                 NaN
#
#     fatigue_1_match_AWAY  fatigue_2_match_AWAY  fatigue_3_match_AWAY  \
# 0                    NaN                   NaN                   NaN
# 20                   5.0                  14.0                   NaN
# 39                   9.0                  14.0                  23.0
#
#     fatigue_4_match_AWAY  fatigue_5_match_AWAY
# 0                    NaN                   NaN
# 20                   NaN                   NaN
# 39                   NaN                   NaN

# %%
# reorder columns
features = ["GAME_ID","TEAM_ID_HOME","TEAM_ID_AWAY",'gameweek', 'season',
       'possession_home', 'possession_away', 'shot_on_target_home',
       'shot_on_target_away', 'saves_home', 'saves_away', 'year',
       'quarter', 'month', 'week', 'day', 'weekday', 'is_monday',
       'is_tuesday', 'is_wednesday', 'is_thursday', 'is_friday',
       'is_saturday', 'is_sunday', 'shot_total_home', 'shot_total_away',
       'saves_total_home', 'saves_total_away', 'goal_home', 'goal_away',
       'points_result_home', 'points_result_away',
           ]
for i, col in enumerate(features) :
    games.insert(i, col, games.pop(col))

# %%
games.to_csv(DATAPATH / f"games_{filepath}",index=False)
